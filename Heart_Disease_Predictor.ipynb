# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("/Users/nidhi.anil/Downloads/heart_2020_indicators.csv")
data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No               3
# 1                No  20.34      No              No    Yes               0
# 2                No  26.58     Yes              No     No              20
# 3                No  24.21      No              No     No               0
# 4                No  23.71      No              No     No              28
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No               7
# 319791           No  29.84     Yes              No     No               0
# 319792           No  24.24      No              No     No               0
# 319793           No  32.81      No              No     No               0
# 319794           No  46.56      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
data.shape
# Out:
# (319795, 18)

# %%
data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DiffWalking       319019 non-null  object
#  8   Sex               319435 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              318654 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         318999 non-null  object
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  object
# ...

# %%
data.duplicated().sum()
# Out:
# 17923

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (301872, 18)

# %%
data.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  301872.000000   301872.000000  301872.000000  301872.000000
# mean       28.441303        3.570464       4.119421       7.084625
# std         6.467112        8.138969       8.126729       1.466859
# min        12.020000        0.000000       0.000000       1.000000
# 25%        24.030000        0.000000       0.000000       6.000000
# 50%        27.410000        0.000000       0.000000       7.000000
# 75%        31.650000        2.000000       4.000000       8.000000
# max        94.850000       30.000000      30.000000      24.000000

# %%
data.describe(include='object')
# Out:
#        HeartDisease Smoking AlcoholDrinking  Stroke DiffWalking     Sex  \
# count        301872  301872          301872  301872      301096  301512
# unique            2       2               2       2           2       2
# top              No      No              No      No          No  Female
# freq         274608  174428          280289  289808      256919  159548
#
#        AgeCategory    Race Diabetic PhysicalActivity  GenHealth  Asthma  \
# count       301872  300731   301872           301872     301076  301872
# unique          13       6        4                2          5       2
# top          65-69   White       No              Yes  Very good      No
# freq         31692  227063   251946           230557     104634  259218
#
#        KidneyDisease SkinCancer
# count         301872     301872
# unique             2          2
# top               No         No
# freq          290096     272574

# %%
data.isna().sum()
# Out:
# HeartDisease           0
# BMI                    0
# Smoking                0
# AlcoholDrinking        0
# Stroke                 0
# PhysicalHealth         0
# MentalHealth           0
# DiffWalking          776
# Sex                  360
# AgeCategory            0
# Race                1141
# Diabetic               0
# PhysicalActivity       0
# GenHealth            796
# SleepTime              0
# Asthma                 0
# KidneyDisease          0
# SkinCancer             0
# dtype: int64

# %%
data.HeartDisease.value_counts()
# Out:
# No     274608
# Yes     27264
# Name: HeartDisease, dtype: int64

# %%
data['HeartDisease'].describe()
# Out:
# count     301872
# unique         2
# top           No
# freq      274608
# Name: HeartDisease, dtype: object

# %%
##numerical variables
numerical = list(data.select_dtypes(include=['int64','float64']).keys())
numerical
# Out:
# ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']

# %%
#categorical variables

categorical = list(data.select_dtypes(include='O').keys())
categorical
# Out:
# ['HeartDisease',
#  'Smoking',
#  'AlcoholDrinking',
#  'Stroke',
#  'DiffWalking',
#  'Sex',
#  'AgeCategory',
#  'Race',
#  'Diabetic',
#  'PhysicalActivity',
#  'GenHealth',
#  'Asthma',
#  'KidneyDisease',
#  'SkinCancer']

# %%
sns.countplot(x='HeartDisease',data=data)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)

sns.barplot(x="HeartDisease", y="BMI", data=data)
plt.subplot(132)

sns.barplot(x="HeartDisease", y="PhysicalHealth", data=data)
plt.subplot(133)

sns.barplot(x="HeartDisease", y="MentalHealth", data=data)
plt.subplot(133)

plt.show()

# %% [markdown]
# # Percentage of patients having HeartDisease

# %%
plt.pie(data.HeartDisease.value_counts(), labels=data.HeartDisease.value_counts().index,autopct='%.0f%%')
plt.legend(title='Segments')
plt.show()

# %%
data.BMI.describe()
# Out:
# count    301872.000000
# mean         28.441303
# std           6.467112
# min          12.020000
# 25%          24.030000
# 50%          27.410000
# 75%          31.650000
# max          94.850000
# Name: BMI, dtype: float64

# %%
data.BMI.value_counts()
# Out:
# 26.63    3247
# 27.46    2427
# 27.44    2391
# 24.41    2177
# 27.12    2063
#          ...
# 63.85       1
# 48.34       1
# 30.97       1
# 68.16       1
# 46.56       1
# Name: BMI, Length: 3604, dtype: int64

# %%
interval = [12,16,17,18.5,25,30,35,40,95]
names =['Severe Thinness','Moderate Thinness','Mild Thinness','Normal','Overweight','Obese class 1','Obese class 2','Obese class 3']
data['Category']= pd.cut(data.BMI , bins=interval, labels=names)
data.Category.value_counts()
# Out:
# Overweight           105374
# Normal                91319
# Obese class 1         59016
# Obese class 2         24755
# Obese class 3         16321
# Mild Thinness          3512
# Moderate Thinness       886
# Severe Thinness         689
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = data.Category, hue = data.Sex)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
plt.pie(data.Category.value_counts(), labels=data.Category.value_counts().index,autopct='%.0f%%')
plt.show()

# %% [markdown]
# 35% of patients are Overweight , 30% are Normal and 20% are Obese Class one,8% are obese class 2,5% are obese class 3

# %%
    data=data.drop(['Category'],axis=1)

# %%
plt.figure(figsize=(10,4))
sns.countplot(x = data.AgeCategory.sort_values())
# Out:
# <Axes: xlabel='AgeCategory', ylabel='count'>

# %% [markdown]
#  Most patients age are between 65 to 70 and least patients age are 25 to 29

# %%
have_heart_dis=data[data.HeartDisease =='Yes']
sns.countplot(x = have_heart_dis.Smoking ,hue=have_heart_dis.Sex)
# Out:
# <Axes: xlabel='Smoking', ylabel='count'>

# %%
have_heart_dis.Smoking.value_counts()
# Out:
# Yes    15979
# No     11285
# Name: Smoking, dtype: int64

# %%
plt.pie(have_heart_dis.Smoking.value_counts(), labels=have_heart_dis.Smoking.value_counts().index,autopct='%.0f%%')
plt.show()

# %% [markdown]
# 59% of patients that have heart disease are smoked at least 100 cigarettes in their entire life (5 packs = 100 cigarettes)

# %%
haveno_heart_dis=data[data.HeartDisease =='No']
sns.countplot(x = haveno_heart_dis.SleepTime,hue=haveno_heart_dis.Sex )
# Out:
# <Axes: xlabel='SleepTime', ylabel='count'>

# %%
haveno_heart_dis=data[data.HeartDisease =='No']
sns.countplot(x = haveno_heart_dis.Stroke,hue=haveno_heart_dis.Sex )
# Out:
# <Axes: xlabel='Stroke', ylabel='count'>

# %%
haveno_heart_dis=data[data.HeartDisease =='No']
sns.countplot(x = haveno_heart_dis.Diabetic,hue=haveno_heart_dis.Sex )
# Out:
# <Axes: xlabel='Diabetic', ylabel='count'>

# %%
plt.figure(figsize=(10,4))
sns.countplot(x = have_heart_dis.AgeCategory.sort_values() ,hue=have_heart_dis.Sex)
# Out:
# <Axes: xlabel='AgeCategory', ylabel='count'>

# %%
plt.pie(have_heart_dis.Sex.value_counts(), labels=have_heart_dis.Sex.value_counts().index,autopct='%.0f%%')
plt.show()

# %% [markdown]
# 59% of patients that have heart disease are males, 41% are females and the most age that have heart disease are start from 60 to older

# %%
sns.countplot(x = have_heart_dis.GenHealth ,hue=have_heart_dis.Sex)
# Out:
# <Axes: xlabel='GenHealth', ylabel='count'>

# %%
plt.pie(have_heart_dis.GenHealth.value_counts(), labels=have_heart_dis.GenHealth.value_counts().index,autopct='%.0f%%')
plt.show()

# %% [markdown]
# 35% of patient were have good health then 26% were have fair health who that have heart disease

# %% [markdown]
# # Missing value Handling

# %%
data.isna().sum()
# Out:
# HeartDisease           0
# BMI                    0
# Smoking                0
# AlcoholDrinking        0
# Stroke                 0
# PhysicalHealth         0
# MentalHealth           0
# DiffWalking          776
# Sex                  360
# AgeCategory            0
# Race                1141
# Diabetic               0
# PhysicalActivity       0
# GenHealth            796
# SleepTime              0
# Asthma                 0
# KidneyDisease          0
# SkinCancer             0
# Category               0
# dtype: int64

# %%
for col in['DiffWalking','Sex','Race','GenHealth']:
    data[col]=data[col].fillna(data[col].mode()[0])

# %%
data.isna().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# Category            0
# dtype: int64

# %% [markdown]
# # Outlier detection and Handling

# %%
x2=[['PhysicalHealth','MentalHealth','BMI','SleepTime']]

# %%
 for i in x2:
    plt.figure(figsize=(10,10))
    plt.boxplot(data[i])
    plt.title(i)
    plt.show()

# %%
# handling outliers of 'physicalhealth'
Q1=data['PhysicalHealth'].quantile(.25)
Q2=data['PhysicalHealth'].quantile(.50)
Q3=data['PhysicalHealth'].quantile(.75)
print('Q1=',Q1)
print('Q2=',Q2)
print('Q3=',Q3)

IQR = Q3-Q1
print('IQR=',IQR)

up_lmt=Q3+1.5*IQR
low_lmt=Q1-1.5*IQR
print('up_lmt=',up_lmt)
print('low_lmt=',low_lmt)

outlier=[]
for x in data['PhysicalHealth']:
    if (x<low_lmt) or (x>up_lmt):
        outlier.append(x)
print('outliers = ',outlier)
# Out:
# Q1= 0.0
# Q2= 0.0
# Q3= 2.0
# IQR= 2.0
# up_lmt= 5.0
# low_lmt= -3.0
# ...

# %%
data1=data[(data['PhysicalHealth']>low_lmt) & (data['PhysicalHealth']< up_lmt)]
print("Initial rows and columns:", data.shape)
print("After dropping,count of rows and columns:",data1.shape)
# Out:
# Initial rows and columns: (301872, 19)
# After dropping,count of rows and columns: (247146, 19)

# %%
# handling outliers of MentalHealth
Q1=data['MentalHealth'].quantile(.25)
Q2=data['MentalHealth'].quantile(.50)
Q3=data['MentalHealth'].quantile(.75)
print('Q1=',Q1)
print('Q2=',Q2)
print('Q3=',Q3)

IQR = Q3-Q1
print('IQR=',IQR)

up_lmt=Q3+1.5*IQR
low_lmt=Q1-1.5*IQR
print('up_lmt=',up_lmt)
print('low_lmt=',low_lmt)

outlier=[]
for x in data['MentalHealth']:
    if (x<low_lmt) or (x>up_lmt):
        outlier.append(x)
print('outliers = ',outlier)
# Out:
# Q1= 0.0
# Q2= 0.0
# Q3= 4.0
# IQR= 4.0
# up_lmt= 10.0
# low_lmt= -6.0
# ...

# %%
data1=data[(data['MentalHealth']>low_lmt) & (data['MentalHealth']< up_lmt)]
print("Initial rows and columns:", data.shape)
print("After dropping,count of rows and columns:",data1.shape)
# Out:
# Initial rows and columns: (301872, 19)
# After dropping,count of rows and columns: (251699, 19)

# %%
# handling outliers of BMI
Q1=data['BMI'].quantile(.25)
Q2=data['BMI'].quantile(.50)
Q3=data['BMI'].quantile(.75)
print('Q1=',Q1)
print('Q2=',Q2)
print('Q3=',Q3)

IQR = Q3-Q1
print('IQR=',IQR)

up_lmt=Q3+1.5*IQR
low_lmt=Q1-1.5*IQR
print('up_lmt=',up_lmt)
print('low_lmt=',low_lmt)

outlier=[]
for x in data['BMI']:
    if (x<low_lmt) or (x>up_lmt):
        outlier.append(x)
print('outliers = ',outlier)
# Out:
# Q1= 24.03
# Q2= 27.41
# Q3= 31.65
# IQR= 7.619999999999997
# up_lmt= 43.08
# low_lmt= 12.600000000000005
# ...

# %%
data1=data[(data['BMI']>low_lmt) & (data['BMI']< up_lmt)]
print("Initial rows and columns:", data.shape)
print("After dropping,count of rows and columns:",data1.shape)
# Out:
# Initial rows and columns: (301872, 19)
# After dropping,count of rows and columns: (292959, 19)

# %%
# handling outliers of SleepTime
Q1=data['SleepTime'].quantile(.25)
Q2=data['SleepTime'].quantile(.50)
Q3=data['SleepTime'].quantile(.75)
print('Q1=',Q1)
print('Q2=',Q2)
print('Q3=',Q3)

IQR = Q3-Q1
print('IQR=',IQR)

up_lmt=Q3+1.5*IQR
low_lmt=Q1-1.5*IQR
print('up_lmt=',up_lmt)
print('low_lmt=',low_lmt)

outlier=[]
for x in data['SleepTime']:
    if (x<low_lmt) or (x>up_lmt):
        outlier.append(x)
print('outliers = ',outlier)
# Out:
# Q1= 6.0
# Q2= 7.0
# Q3= 8.0
# IQR= 2.0
# up_lmt= 11.0
# low_lmt= 3.0
# ...

# %%
data1=data[(data['SleepTime']>low_lmt) & (data['SleepTime']< up_lmt)]
print("Initial rows and columns:", data.shape)
print("After dropping,count of rows and columns:",data1.shape)
# Out:
# Initial rows and columns: (301872, 19)
# After dropping,count of rows and columns: (294923, 19)

# %%
data1.shape
# Out:
# (294923, 19)

# %%
data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer', 'Category'],
#       dtype='object')

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data1['HeartDisease']=le.fit_transform(data1['HeartDisease'])
data1['Smoking']=le.fit_transform(data1['Smoking'])
data1['AlcoholDrinking']=le.fit_transform(data1['AlcoholDrinking'])
data1['Stroke']=le.fit_transform(data1['Stroke'])
data1['DiffWalking']=le.fit_transform(data1['DiffWalking'])
data1['Sex']=le.fit_transform(data1['Sex'])
data1['PhysicalActivity']=le.fit_transform(data1['PhysicalActivity'])
data1['Asthma']=le.fit_transform(data1['Asthma'])
data1['KidneyDisease']=le.fit_transform(data1['KidneyDisease'])
data1['SkinCancer']=le.fit_transform(data1['SkinCancer'])
data1['Race']=le.fit_transform(data1['Race'])
data1['Diabetic']=le.fit_transform(data1['Diabetic'])
data1['PhysicalActivity']=le.fit_transform(data1['PhysicalActivity'])
data1['GenHealth']=le.fit_transform(data1['GenHealth'])
data1['Category']=le.fit_transform(data1['Category'])
data1['AgeCategory']=le.fit_transform(data1['AgeCategory'])
# Out:
# /var/folders/rh/zmjyr39j5y9_jmlgy4_cl6600000gp/T/ipykernel_39041/2673656830.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['HeartDisease']=le.fit_transform(data1['HeartDisease'])
# /var/folders/rh/zmjyr39j5y9_jmlgy4_cl6600000gp/T/ipykernel_39041/2673656830.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Smoking']=le.fit_transform(data1['Smoking'])
# /var/folders/rh/zmjyr39j5y9_jmlgy4_cl6600000gp/T/ipykernel_39041/2673656830.py:5: SettingWithCopyWarning:
# ...

# %% [markdown]
# data2=pd.get_dummies(data1)

# %%
data1
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0               3
# 1                  0  20.34        0                0       1               0
# 2                  0  26.58        1                0       0              20
# 3                  0  24.21        0                0       0               0
# 4                  0  23.71        0                0       0              28
# ...              ...    ...      ...              ...     ...             ...
# 319789             0  22.22        0                0       0               0
# 319790             1  27.41        1                0       0               7
# 319791             0  29.84        1                0       0               0
# 319792             0  24.24        0                0       0               0
# 319794             0  46.56        0                0       0               0
#
# ...

# %% [markdown]
# data2.shape

# %%
data['AgeCategory'].nunique()
# Out:
# 13

# %%
data['Race'].nunique()
# Out:
# 6

# %%
data['GenHealth'].nunique()
# Out:
# 5

# %%
data2.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0               3
# 1             0  20.34        0                0       1               0
# 2             0  26.58        1                0       0              20
# 3             0  24.21        0                0       0               0
# 4             0  23.71        0                0       0              28
#
#    MentalHealth  DiffWalking  Sex  PhysicalActivity  ...  Race_White  \
# 0            30            0    0                 1  ...           1
# 1             0            0    0                 1  ...           1
# 2            30            0    1                 1  ...           1
# 3             0            0    0                 0  ...           1
# 4             0            1    0                 1  ...           1
#
#    Diabetic_No  Diabetic_No, borderline diabetes  Diabetic_Yes  \
# ...

# %% [markdown]
# # Modelling

# %%
# Prepare the data
X = data1.drop(['HeartDisease'], axis=1)
y = data1['HeartDisease']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.25,random_state=42)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model=lr.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
y_pred,y_test
# Out:
# (array([ 0.17351846,  0.02934227, -0.05084469, ...,  0.181506  ,
#          0.22153359, -0.04897639]),
#  317382    0
#  272307    0
#  88476     0
#  38506     0
#  111141    0
#           ..
#  283789    0
#  49350     0
#  83007     0
#  270013    0
#  305081    0
#  Name: HeartDisease, Length: 73731, dtype: int64)

# %% [markdown]
# LogisticRegression Model

# %%
from sklearn.linear_model import LogisticRegression
logit_reg = LogisticRegression()
logit_reg.fit(X_train,y_train)
# Out:
# /Users/nidhi.anil/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# prediction
pred = logit_reg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score

# %%
print('accuracy =',accuracy_score(y_test,pred))
print('precision =',precision_score(y_test,pred,average='macro'))
print('recall =',recall_score(y_test,pred,average='macro'))
print('f1_score =',f1_score(y_test,pred,average='macro'))

confusion_matrix(y_test,pred)
# Out:
# accuracy = 0.912533398434851
# precision = 0.7196473997254842
# recall = 0.5404004604373798
# f1_score = 0.5527244694854678
# array([[66706,   530],
#        [ 5919,   576]])

# %% [markdown]
# KNN

# %%
X_test
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 317382  32.32        0                0       0              30             0
# 272307  22.32        0                0       0               0             4
# 88476   18.88        0                0       0               0             0
# 38506   28.34        0                0       0              30            15
# 111141  28.19        0                0       0               0             0
# ...       ...      ...              ...     ...             ...           ...
# 283789  25.10        1                0       0               0            30
# 49350   24.39        0                0       0               0             0
# 83007   28.21        0                1       0               0             0
# 270013  27.26        0                0       0               2            30
# 305081  33.47        0                0       0               0             0
#
# ...

# %%
X_test.columns
# Out:
# Index(['BMI', 'Smoking', 'AlcoholDrinking', 'Stroke', 'PhysicalHealth',
#        'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic',
#        'PhysicalActivity', 'GenHealth', 'SleepTime', 'Asthma', 'KidneyDisease',
#        'SkinCancer', 'Category'],
#       dtype='object')

# %% [markdown]
# # Exporting to Pickle File

# %%
import pickle

# %%
pickle.dump(logit_reg , open("LR_Model.pkl", "wb"))
